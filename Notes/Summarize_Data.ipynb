# %% [markdown]
# # Summarize Data
#
# Average, Variance, Correlation, Ratio

# %% [markdown]
# Mean: The Average value in a dataset.
#
# Median: The Middle value in a dataset.
#
# Mode: The Value that is frequent in a dataset.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.DataFrame({'rating': [1, 2, 3, 4, 6, 7, 9, 9, 9, 10], 'dummy': range(10)})
df
# Out:
#    rating  dummy
# 0       1      0
# 1       2      1
# 2       3      2
# 3       4      3
# 4       6      4
# 5       7      5
# 6       9      6
# 7       9      7
# 8       9      8
# 9      10      9

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)})
mean=df['rating'].mean()
median=df['rating'].median()
mode=df['rating'].mode().values[0]

sns.boxplot(data=df, x="rating", ax=ax_box)
ax_box.axvline(mean, color='r', linestyle='--')
ax_box.axvline(median, color='g', linestyle='-')
ax_box.axvline(mode, color='b', linestyle='-')

sns.histplot(data=df, x="rating", ax=ax_hist, kde=True)
ax_hist.axvline(mean, color='r', linestyle='--', label="Mean")
ax_hist.axvline(median, color='g', linestyle='-', label="Median")
ax_hist.axvline(mode, color='b', linestyle='-', label="Mode")

ax_hist.legend()

ax_box.set(xlabel='')
plt.show()

# %% [markdown]
# The measure of dispersion that quantifies the spread or variability of data points.
#
# Variance Calculation: It is the average of the squared differences between each data point and the mean.
#
# Standard Deviation: The square root of the variance; provides a more intuitive understanding of data spread.
#
# Use Cases: Assessing data consistency, identifying outliers, comparing variability.

# %%
import numpy as np

data = np.random.normal(loc=0, scale=1, size=100)

variance = np.var(data)

plt.figure(figsize=(10,6))

plt.hist(data, bins=20, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Histogram of Example Data')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.axvline(np.mean(data), color='red', linestyle='dashed', linewidth=1, label='Mean')

plt.axvline(np.mean(data) - np.std(data), color='green', linestyle='dashed', linewidth=1, label='-1 Std Dev')
plt.axvline(np.mean(data) + np.std(data), color='green', linestyle='dashed', linewidth=1, label='+1 Std Dev')

plt.legend()
plt.grid()
plt.show()

print(f"variance: {variance:.2f}")
# Out:
# variance: 0.89

# %%
exam_scores = [85, 92, 78, 90, 88, 95, 85, 80, 82, 92]

variance = np.var(exam_scores)

plt.figure(figsize=(10, 6))

plt.hist(exam_scores, bins=10, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Histogram of Exam Scores')
plt.xlabel('Score')
plt.ylabel('Frequency')

plt.axvline(np.mean(exam_scores), color='red', linestyle='dashed', linewidth=1, label='Mean')

plt.axvline(np.mean(exam_scores) - np.std(exam_scores), color='green', linestyle='dashed', linewidth=1, label='-1 Std Dev')
plt.axvline(np.mean(exam_scores) + np.std(exam_scores), color='green', linestyle='dashed', linewidth=1, label='+1 Std Dev')

plt.legend()
plt.grid()
plt.show()

print(f"Variance: {variance:.2f}")
# Out:
# Variance: 28.61

# %% [markdown]
# The measure of the strength and direction of a linear relationship between two variables.
#
# Pearson Correlation Coefficient: Ranges from -1 to 1, where -1 indicates a perfect negative linear correlation, 1 indicates a perfect positive linear correlation, and 0 indicates no linear correlation.
#
# Scatter Plots: Visualization tool for understanding correlation.
#
# Use Cases: Identifying relationships between variables, predicting one variable from another.

# %%
from scipy.stats import pearsonr, spearmanr, kendalltau

x = np.array([1,2,3,4,5])
y = np.array([2,4,5,4,6])

pearson_corr, _ = pearsonr(x,y)

spearman_corr, _ = spearmanr(x,y)

kendall_corr, _ = kendalltau(x,y)

print(f"Pearson correlation: {pearson_corr:.2f}")
print(f"Spearman correlation: {spearman_corr:.2f}")
print(f"Kendall correlation: {kendall_corr:.2f}")
# Out:
# Pearson correlation: 0.85
# Spearman correlation: 0.82
# Kendall correlation: 0.74

# %% [markdown]
# The quantitative relationship between two amounts, often expressed as a fraction or quotient.
#
# Ratio Calculation: Division of one quantity by another.
#
# Importance in Business: Profit margins, financial ratios (e.g., debt-to-equity ratio), performance indicators.
#
# Use Cases: Financial analysis, Performance evalutaion, decision-making.

# %%
periods = ['Jan', 'Feb', 'Mar', 'Apr', 'May']
profits = [15000, 18000, 22000, 16000, 19000]

base_profit = profits[0]
profit_ratio = [profit / base_profit for profit in profits]

plt.figure(figsize=(10, 6))

plt.bar(periods, profit_ratio, color='skyblue')
plt.title('Profit Ratio by Period')
plt.xlabel('Period')
plt.ylabel('Profit Ratio')
plt.ylim(0, max(profit_ratio) * 1.2)

plt.grid()
plt.show()

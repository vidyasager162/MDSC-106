# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_excel('./Shopping Trends - Q2/shopping_trends.xlsx')
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
px.pie(df, names='Gender')

# %%
px.bar(df, x='Item Purchased', y='Customer ID', facet_col='Gender')

# %%
px.pie(df, names='Category')

# %%
px.bar(df, x='Category', y='Customer ID', facet_col='Gender')

# %%
px.bar(df, x='Location', y='Customer ID', facet_col='Gender')

# %%
px.pie(df, names='Size')

# %%
px.bar(df, x='Size', y='Customer ID', facet_col='Gender')

# %%
px.bar(df, x='Color', y='Customer ID', facet_col='Gender')

# %%
px.pie(df, names='Season')

# %%
px.bar(df, x='Season', y='Customer ID', facet_col='Gender')

# %%
px.pie(df, names='Subscription Status')

# %%
px.bar(df, x='Subscription Status', y='Customer ID', facet_col='Gender')

# %%
px.pie(df, names='Shipping Type')

# %%
px.bar(df, x='Shipping Type', y='Customer ID', facet_col='Gender')

# %%
px.pie(df, names='Discount Applied')

# %%
px.bar(df, x='Discount Applied', y='Customer ID', facet_col='Gender')

# %%
px.pie(df, names='Promo Code Used')

# %%
px.bar(df, x='Promo Code Used', y='Customer ID', facet_col='Gender')

# %%
px.scatter(df, x='Customer ID', y='Previous Purchases', facet_col='Gender')

# %%
px.pie(df, names='Payment Method')

# %%
px.bar(df, x='Payment Method', y='Customer ID', facet_col='Gender')

# %%
px.pie(df, names='Frequency of Purchases')

# %%
px.bar(df, x='Frequency of Purchases', y='Customer ID', facet_col='Gender')

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df['Gender'] = [0 if gender == 'Male' else 1 for gender in df['Gender']]
df['Subscription Status'] = [0 if status == 'No' else 1 for status in df['Subscription Status']]
df['Discount Applied'] = [0 if x == 'No' else 1 for x in df['Discount Applied']]
df['Promo Code Used'] = [0 if x == 'No' else 1 for x in df['Promo Code Used']]

# %%
df.head()
# Out:
#    Customer ID  Age  Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55       0         Blouse  Clothing                     53
# 1            2   19       0        Sweater  Clothing                     64
# 2            3   50       0          Jeans  Clothing                     73
# 3            4   21       0        Sandals  Footwear                     90
# 4            5   45       0         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating  Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                    1
# 1          Maine    L     Maroon  Winter            3.1                    1
# 2  Massachusetts    S     Maroon  Spring            3.1                    1
# 3   Rhode Island    M     Maroon  Spring            3.5                    1
# 4         Oregon    M  Turquoise  Spring            2.7                    1
#
# ...

# %%
plt.subplots(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

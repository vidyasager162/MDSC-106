# %% [markdown]
# # MDSC-106
#
# ## Task-1

# %% [markdown]
# We begin with reading the two provided datasets (TelecomCustomer-Churn_1.csv and TelecomCustomer-Churn_2.csv) into data frames.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
telecom1_data = pd.read_csv("./archive/TelcomCustomer-Churn_1.csv")
telecom1_data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity
# 0              No  No phone service             DSL             No
# ...

# %%
telecom2_data = pd.read_csv("./archive/TelcomCustomer-Churn_2.csv")
telecom2_data
# Out:
#       customerID OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0     7590-VHVEG          Yes               No          No          No
# 1     5575-GNVDE           No              Yes          No          No
# 2     3668-QPYBK          Yes               No          No          No
# 3     7795-CFOCW           No              Yes         Yes          No
# 4     9237-HQITU           No               No          No          No
# ...          ...          ...              ...         ...         ...
# 7038  6840-RESVB           No              Yes         Yes         Yes
# 7039  2234-XADUH          Yes              Yes          No         Yes
# 7040  4801-JZAZL           No               No          No          No
# 7041  8361-LTMKD           No               No          No          No
# 7042  3186-AJIEK           No              Yes         Yes         Yes
#
#      StreamingMovies        Contract PaperlessBilling  \
# 0                 No  Month-to-month              Yes
# ...

# %%
telecom_data = pd.merge(telecom1_data, telecom2_data, on='customerID')
telecom_data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
telecom_data.columns == (telecom1_data.columns.union(telecom2_data.columns, sort=False))
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
telecom_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
telecom_data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
telecom_data['SeniorCitizen'].value_counts()
# Out:
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %%
telecom_data['TotalCharges']
# Out:
# 0         29.85
# 1        1889.5
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038     1990.5
# 7039     7362.9
# 7040     346.45
# 7041      306.6
# 7042     6844.5
# Name: TotalCharges, Length: 7043, dtype: object

# %%
telecom_data['TotalCharges'] = pd.to_numeric(telecom_data['TotalCharges'], errors='coerce')
telecom_data['TotalCharges'].fillna(0.0, inplace=True)

# %%
telecom_data['TotalCharges']
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %%
telecom_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
def throwPie(df, columns):
    all_labels = []
    all_sizes = []
    all_titles = []
    for column in columns:
        series = df[column].value_counts()
        sizes = []
        labels = []
        titles = []
        titles.append(column)
        for x in range(len(series.index)):
            labels.append(series.index[x])
        for attr in series:
            sizes.append(attr)
        all_titles.append(titles)
        all_sizes.append(sizes)
        all_labels.append(labels)
        # ax[index].set_title(column)
        # ax[index].pie(sizes, labels=labels, autopct='%1.1f%%')
    rows = math.ceil(len(columns) / 3 )
    cols = math.ceil(len(columns) / rows)
    fig, ax = plt.subplots(rows, cols, figsize=(30, 30))
    count = 0
    for row in range(rows):
        for col in range(cols):
            if count >= len(columns):
                break
            fig.suptitle("Analysing Categorical Features")
            ax[row,col].set_title(all_titles[count])
            ax[row, col].pie(all_sizes[count], labels=all_labels[count], autopct='%1.1f%%')
            count += 1
            
    fig.savefig("piechart")

# %%
columns = ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'Churn']

# %%
throwPie(telecom_data, columns)

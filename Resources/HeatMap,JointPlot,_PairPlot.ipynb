# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_normal = pd.read_csv(r'C:\Users\vijet\Downloads\MDH Lab exercises\Normal.csv')
df_typeH = pd.read_csv(r'C:\Users\vijet\Downloads\MDH Lab exercises\Type_H.csv')
df_typeS = pd.read_csv(r'C:\Users\vijet\Downloads\MDH Lab exercises\Type_S.csv')

# %%
df = pd.concat([df_normal, df_typeH], ignore_index = True)
df = pd.concat([df, df_typeS], ignore_index = True)

# %%
df.corr()
# Out:
# C:\Users\vijet\AppData\Local\Temp\ipykernel_18124\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              P_incidence    P_tilt   L_angle   S_slope  P_radius  S_Degree
# P_incidence     1.000000  0.629199  0.717282  0.814960 -0.247467  0.638743
# P_tilt          0.629199  1.000000  0.432764  0.062345  0.032668  0.397862
# L_angle         0.717282  0.432764  1.000000  0.598387 -0.080344  0.533667
# S_slope         0.814960  0.062345  0.598387  1.000000 -0.342128  0.523557
# P_radius       -0.247467  0.032668 -0.080344 -0.342128  1.000000 -0.026065
# S_Degree        0.638743  0.397862  0.533667  0.523557 -0.026065  1.000000

# %%
df
# Out:
#      P_incidence     P_tilt    L_angle    S_slope    P_radius    S_Degree  \
# 0      38.505273  16.964297  35.112814  21.540976  127.632875    7.986683
# 1      54.920858  18.968430  51.601455  35.952428  125.846646    2.001642
# 2      44.362490   8.945435  46.902096  35.417055  129.220682    4.994195
# 3      48.318931  17.452121  48.000000  30.866809  128.980308   -0.910941
# 4      45.701789  10.659859  42.577846  35.041929  130.178314   -3.388910
# ..           ...        ...        ...        ...         ...         ...
# 305    80.111572  33.942432  85.101608  46.169139  125.593624  100.292107
# 306    95.480229  46.550053  59.000000  48.930176   96.683903   77.283072
# 307    74.094731  18.823727  76.032156  55.271004  128.405731   73.388216
# 308    87.679087  20.365613  93.822416  67.313473  120.944829   76.730629
# 309    48.259920  16.417462  36.329137  31.842457   94.882336   28.343799
#
#       Class
# 0    Normal
# 1    Normal
# 2    Normal
# 3    Normal
# ...

# %%
type(df.P_incidence)
# Out:
# pandas.core.series.Series

# %%
df['P_incidence']
# Out:
# 0      38.505273
# 1      54.920858
# 2      44.362490
# 3      48.318931
# 4      45.701789
#          ...
# 305    80.111572
# 306    95.480229
# 307    74.094731
# 308    87.679087
# 309    48.259920
# Name: P_incidence, Length: 310, dtype: float64

# %%
type(df['P_incidence'])
# Out:
# pandas.core.series.Series

# %%
df[['P_incidence']]
# Out:
#      P_incidence
# 0      38.505273
# 1      54.920858
# 2      44.362490
# 3      48.318931
# 4      45.701789
# ..           ...
# 305    80.111572
# 306    95.480229
# 307    74.094731
# 308    87.679087
# 309    48.259920
#
# [310 rows x 1 columns]

# %%
type(df[['P_incidence']])
# Out:
# pandas.core.frame.DataFrame

# %%
sns.heatmap(df.corr())
plt.show()
# Out:
# C:\Users\vijet\AppData\Local\Temp\ipykernel_10480\2796311861.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())

# %%
sns.heatmap(df.corr(), cmap='coolwarm', annot=True)
plt.show()
# Out:
# C:\Users\vijet\AppData\Local\Temp\ipykernel_10480\1621615101.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), cmap='coolwarm', annot=True)

# %% [markdown]
# # Pairplot:

# %%
sns.pairplot(df, hue="Class")

# %% [markdown]
# # Jointplot:

# %%
sns.jointplot(data=df, x="P_incidence", y="S_slope")
